# %% [markdown]
# # Sistem Nilai — Pertemuan 03

# %%
def grade(n):
    if n < 0 or n > 100: return 'INVALID'
    if n >= 90: return 'A'
    if n >= 80: return 'B'
    if n >= 75: return 'C / Lulus'
    return 'Belum lulus'
nilai=float(input('Nilai: '))
print(grade(nilai))
