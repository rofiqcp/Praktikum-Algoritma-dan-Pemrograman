# %% [markdown]
# # Pertemuan 05 — List, Dictionary, Statistik

# %%
nilai=[80,75,90,68,88]
print('Jumlah',len(nilai),'Min',min(nilai),'Max',max(nilai),'Rata',sum(nilai)/len(nilai))

# %%
produk={'nama':'Keyboard','harga':250000,'stok':10}
print(produk['nama'],produk.get('stok'))

# %%
data=[]
print('List kosong ditangani:', 'tidak ada rata-rata' if not data else sum(data)/len(data))
